# %% [markdown]
# <a href="https://colab.research.google.com/github/vxkudire/python-basic-agents/blob/main/python-fundas/Python_deepdive3_oop_filehandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Fundamentals - Week 3

# %% [markdown]
# ### Scope of Variables

# %% [markdown]
# #### Class Activity

# %% [markdown]
# #### Local Variables

# %% [markdown]
# What is the output of the code below:

# %%
def example_function():
    local_var = 5
    print(local_var)

# local_var = 6
example_function()
print(local_var)
# Out:
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-20f145d68908> in <cell line: 7>()
#       5 # local_var = 6
#       6 example_function()
# ----> 7 print(local_var)
#
# NameError: name 'local_var' is not defined

# %% [markdown]
# #### Nonlocal Variables

# %% [markdown]
# What is the output of the code below:

# %%
def outer_function():
    nonlocal_var = 10

    def inner_function():
        nonlocal nonlocal_var
        nonlocal_var += 5

    inner_function()
    print(nonlocal_var)

outer_function()

# %% [markdown]
# #### Global Variables

# %% [markdown]
# What is the output of the code below:

# %%
global_var = 20

def example_function():
    global global_var
    global_var += 5
#     print(global_var)

print(global_var)
example_function()
print(global_var)

# %% [markdown]
# ### OOP Concepts

# %% [markdown]
# #### Create a New Class

# %%
# How to create a class
class Student:

    # Define a method
    def walk(self):
        print("Hey, I am walking")

# Create an object
student = Student()

# %%
print(type(student))
# Out:
# <class '__main__.Student'>

# %%
# Call a method in class
student.walk()
# Out:
# Hey, I am walking

# %%
# Add attributes to different objects
student.name = "Matt"
student.age = 25

print(student.name)
print(student.age)
# Out:
# Matt
# 25

# %%
# Create another object
student2 = Student()

student2.gpa = 3.5

print(student2.gpa)
# Out:
# 3.5

# %%
student2.walk()
# Out:
# Hey, I am walking

# %%
student2.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 student2.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %% [markdown]
# #### Class (Cont.)

# %%
# Example of a class
class Dog:

    # Define Constructor
    def __init__(self, name, age, wt):

        # Define Attributes
        self.name = name
        self.age = age
        self.wt = wt

        print("Created a new dog object: " + name)

    # Define a Method
    def walk(self):
        print("I am walking: " + self.name)

    # Change default
    def __repr__(self):
        return "name: " + self.name + ", wt: " + str(self.wt)

# %%
dog1 = Dog("Sky", 12, 5)
# Out:
# Created a new dog object: Sky

# %%
dog1.walk()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 dog1.walk()
#
# TypeError: Dog.walk() takes 0 positional arguments but 1 was given

# %%
print(dog1)
# Out:
# name: Sky, wt: 5

# %%
print(dog1.age)
# Out:
# 12

# %%
# Function with an object attribute
def fun(dog: Dog):
    print("The original name:", dog.name)
    dog.name = "Mooch"
    print("The new name:", dog.name)

# %%
fun(dog1)
# Out:
# The original name: Sky
# The new name: Mooch

# %%
print(dog1)
# Out:
# name: Mooch, wt: 5

# %%
# Create another object
dog2 = Dog("Sheru", 20, 15)
# Out:
# Created a new dog object: Sheru

# %%
# Add objects to a list
list1 = []

list1.append((dog1.name, dog1.age))
list1.append((dog2.name, dog2.age))

print(list1)
# Out:
# [('Mooch', 12), ('Sheru', 20)]

# %% [markdown]
# #### Class Activity

# %%
class Student:

    # Constructor
    def __init__(self, age, name, gpa):
        self.age = age
        self.name = name
        self.gpa = gpa

    # Representation
    def __repr__(self):
        return "Student = " + self.name


class Course:

    # Constructor
    def __init__(self, name):
        self.name = name
        self.list_of_learners = []

    # Write a method to enroll students
    def add_a_student(self, student_obj):
        self.list_of_learners.append(student_obj)

    # Write a method to find the top student (from their gpa) --> return top_student
    def find_top(self):
        max_gpa = 0
        top = None
        for student in self.list_of_learners:
            if student.gpa > max_gpa:
                max_gpa = student.gpa
                top = student
        return top

# %%
student_A = Student(25, "Mary", 4)
student_B = Student(28, "Sarah", 3)
student_C = Student(27, "Jill", 2.5)

math_course = Course("Math")

math_course.add_a_student(student_A)
math_course.add_a_student(student_B)
math_course.add_a_student(student_C)

print(math_course.list_of_learners)
print()

top_student = math_course.find_top()
print(top_student.age)
print(top_student.name)
print(top_student.gpa)
# Out:
# [Student = Mary, Student = Sarah, Student = Jill]
#
# 25
# Mary
# 4

# %% [markdown]
# #### Some Attributes Methods

# %%
class Employee:

    # Constructor
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    # Representation
    def __repr__(self):
        return '{' + self.name + ', ' + str(self.salary) + '}'


employee1 = Employee("Matt", 2000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 class Employee:
#       3     self.new_var = 3
#       6     # Constructor
#
# Cell In[50], line 3, in Employee()
#       1 class Employee:
# ----> 3     self.new_var = 3
#       6     # Constructor
#       7     def __init__(self, name, salary):
#
# NameError: name 'self' is not defined

# %%
# Check existence of an attribute
hasattr(employee1, 'salary')
# Out:
# True

# %%
# Get the value of an attribute
getattr(employee1, 'salary')
# Out:
# 2000

# %%
# Set the value of an attribute
setattr(employee1, 'salary', 7000)
getattr(employee1, 'salary')
# Out:
# 7000

# %%
# Delete an attribute
delattr(employee1, 'salary')
getattr(employee1, 'salary')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 3
#       1 # Delete an attribute
#       2 delattr(employee1, 'salary')
# ----> 3 getattr(employee1, 'salary')
#
# AttributeError: 'Employee' object has no attribute 'salary'

# %% [markdown]
# #### Inheritance

# %%
class Book:
    def __init__(self, title, quantity, author, price):
        self.title = title
        self.quantity = quantity
        self.author = author
        self.__price = price
        self.__discount = None

    def set_discount(self, discount):
        self.__discount = discount

    def get_price(self):
        if self.__discount:
            return self.__price * (1-self.__discount)
        return self.__price

    def __repr__(self):
        return f"Book: {self.title}, Quantity: {self.quantity}, Author: {self.author}, Price: {self.get_price()}"


# New class that inherits from Book
class Novel(Book):
    def __init__(self, title, quantity, author, price, pages):
        super().__init__(title, quantity, author, price)
        self.pages = pages


# Another new class that inherits from Book
class Academic(Book):
    def __init__(self, title, quantity, author, price, branch):
        super().__init__(title, quantity, author, price)
        self.branch = branch

# %%
novel1 = Novel('2 States', 20, 'Matt', 200, 187)
novel1.set_discount(0.20)

academic1 = Academic('Python Foundations', 12, 'PSF', 655, 'IT')

print(novel1)
print(academic1)
# Out:
# Book: 2 States, Quantity: 20, Author: Matt, Price: 160.0
# Book: Python Foundations, Quantity: 12, Author: PSF, Price: 655

# %% [markdown]
# #### Multiple Inheritance

# %%
class A:
    def method_a(self):
        print("Method A from class A")

class B:
    def method_b(self):
        print("Method B from class B")

class C(A, B):
    def method_c(self):
        print("Method C from class C")

# Creating an object of class C
obj = C()

# Calling methods inherited from class A
obj.method_a()  # Output: Method A from class A

# Calling methods inherited from class B
obj.method_b()  # Output: Method B from class B

# Calling method defined in class C
obj.method_c()  # Output: Method C from class C
# Out:
# Method A from class A
# Method B from class B
# Method C from class C

# %% [markdown]
# #### Encapsulation

# %%
# Public
class MyClass:
    def __init__(self):
        self.public_attribute = 42

    def public_method(self):
        return "This is a public method"

obj = MyClass()

print(obj.public_attribute)  # Accessing a public attribute
print(obj.public_method())   # Accessing a public method
# Out:
# 42
# This is a public method

# %%
# Protected
class MyClass:
    def __init__(self):
        self._protected_attribute = 42

    def _protected_method(self):
        return "This is a protected method"

obj = MyClass()

print(obj._protected_attribute)  # Accessing a protected attribute (not recommended)
print(obj._protected_method())   # Accessing a protected method (not recommended)
# Out:
# 42
# This is a protected method

# %%
# Private
class MyClass:
    def __init__(self):
        self.__private_attribute = 42

    def __private_method(self):
        return "This is a private method"

    def _protected_method(self):
        return "This is a protected method"

obj = MyClass()

# Attempting to access a private attribute or method directly will result in an AttributeError.
print(obj.__private_attribute)  # This will raise an AttributeError
print(obj.__private_method())   # This will raise an AttributeError
print(obj._protected_method())   # This will NOT raise an AttributeError
# Out:
# This is a protected method

# %% [markdown]
# #### Getters and Setters

# %%
# Getters and Setters (enforce rules and validation logic)

class Person:

    def __init__(self, name, age):
        self.name = name # public attribute
        self._age = age  # protected attribute

    # getter method
    def get_age(self):
        if (self._age < 0):
            print("This is not a valid age")
            return -1
        return self._age

    # setter method
    def set_age(self, x):
        if x < 0:
            self._age = 0
        self._age = x


p1 = Person("Matt", 20)

# retrieving age using getter
print(p1.get_age())

# setting the age using setter
p1.set_age(21)

# retrieving age using getter
print(p1.get_age())

# Accessing protected attribute
print(p1._age)

# NOTE: Not the best practice to access a protected/private value of a dictionary with getters
# Out:
# 20
# 21
# 21

# %% [markdown]
# #### Polymorphism

# %%
class Shape:
    def area(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14159 * self.radius ** 2


class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height


def calculate_area(shape):
    return shape.area()

# %%
# Create instances of Circle and Rectangle
my_circle = Circle(5)
my_rectangle = Rectangle(4, 6)


# Calculate and print areas using polymorphism
print(f"Circle Area: {calculate_area(my_circle)}")
print(f"Rectangle Area: {calculate_area(my_rectangle)}")
# Out:
# Circle Area: 78.53975
# Rectangle Area: 24

# %% [markdown]
# ### Class Activity (Leetcode Problem)

# %%
class MyHashMap:


    def __init__(self):
        self.my_list = []


    def put(self, key:int, value:int) -> None:

        for pair in self.my_list:
            if key == pair[0]:
                pair[1] = value
                return

        pair = [key, value]
        self.my_list.append(pair)


    def get(self, key:int) -> int:

        for pair in self.my_list:
            if key == pair[0]:
                return pair[1]

        return -1


    def remove(self, key:int) -> None:

        for pair in self.my_list:
            if key == pair[0]:
                self.my_list.remove(pair)
                return

# %%
myHashMap = MyHashMap()

print(myHashMap.my_list)
# Out:
# []

# %%
myHashMap.put(1, 1)
print(myHashMap.my_list)
# Out:
# [[1, 1]]

# %%
myHashMap.put(2, 2)
print(myHashMap.my_list)
# Out:
# [[1, 1], [2, 2]]

# %%
print(myHashMap.get(1))
print(myHashMap.get(2))
print(myHashMap.get(3))
# Out:
# 1
# 2
# -1

# %%
myHashMap.put(2, 1)
print(myHashMap.my_list)
# Out:
# [[1, 1], [2, 1]]

# %%
print(myHashMap.get(2))
# Out:
# 1

# %%
myHashMap.remove(2)
print(myHashMap.my_list)
# Out:
# [[1, 1]]

# %%
print(myHashMap.get(2))
# Out:
# -1

# %% [markdown]
# ### Sort Functions

# %% [markdown]
# #### sorted() vs .sort()

# %%
numbers = [4, 2, 9, 1, 5]

sorted(numbers)

print(numbers)
# Out:
# [4, 2, 9, 1, 5]

# %%
sorted_numbers = sorted(numbers)

print(sorted_numbers)
print(numbers)
# Out:
# [1, 2, 4, 5, 9]
# [4, 2, 9, 1, 5]

# %%
print(numbers)

numbers.sort()

print(numbers)
# Out:
# [4, 2, 9, 1, 5]
# [1, 2, 4, 5, 9]

# %%
print(numbers.sort())
# Out:
# None

# %% [markdown]
# #### key / reverse

# %%
words = ["apple", "banana", "cherry", "date", "fig", "bananas"]

# %%
# sort based on length
sorted_words = sorted(words, key=len)
print(sorted_words)
# Out:
# ['fig', 'date', 'apple', 'banana', 'cherry', 'bananas']

# %%
# sort based on length in reverse order
sorted_words = sorted(words, key=len, reverse=True)
print(sorted_words)
# Out:
# ['bananas', 'banana', 'cherry', 'apple', 'date', 'fig']

# %%
# sort based on the second letter
sorted_words2 = sorted(words, key=lambda x: (x[1], x[0]))
print(sorted_words2)
# Out:
# ['banana', 'bananas', 'date', 'cherry', 'fig', 'apple']

# %% [markdown]
# #### Exercise

# %% [markdown]
# What are the outputs to the following sorts:

# %%
points = [[1,2], [0,4], [6, 3, 2], [1, 3, 1]]

sorted_points1 = sorted(points)
print(sorted_points1)

sorted_points2 = sorted(points, key=lambda x: (x[1]))
print(sorted_points2)

sorted_points3 = sorted(points, key=lambda x: (x[1], x[0]))
print(sorted_points3)
# Out:
# [[0, 4], [1, 2], [1, 3, 1], [6, 3, 2]]
# [[1, 2], [6, 3, 2], [1, 3, 1], [0, 4]]
# [[1, 2], [1, 3, 1], [6, 3, 2], [0, 4]]

# %% [markdown]
# #### Exercise

# %% [markdown]
# Consider the following class:

# %%
class Employee:

    def __init__(self, name, dept, age):
        self.name = name
        self.dept = dept
        self.age = age

    def __repr__(self):
        return '{' + self.name + ', ' + self.dept + ', ' + str(self.age) + '}'

employees = [
        Employee('John', 'IT', 28),
        Employee('Sam', 'Banking', 20),
        Employee('Joe', 'Finance', 25)
]

# %%
employees
# Out:
# [{John, IT, 28}, {Sam, Banking, 20}, {Joe, Finance, 25}]

# %% [markdown]
# Sort the list based on employees names

# %%
sorted_employees_names = sorted(employees, key=lambda x: x.name)
print(sorted_employees_names)
# Out:
# [{Joe, Finance, 25}, {John, IT, 28}, {Sam, Banking, 20}]

# %%
employees.sort(key=lambda x: x.name)

print(employees)
# Out:
# [{Joe, Finance, 25}, {John, IT, 28}, {Sam, Banking, 20}]

# %% [markdown]
# Sort the list based on employees ages

# %%
sorted_employees_ages = sorted(employees, key=lambda x: x.age, reverse=True)
print(sorted_employees_ages)
# Out:
# [{John, IT, 28}, {Joe, Finance, 25}, {Sam, Banking, 20}]

# %% [markdown]
# ### Exception Handling

# %% [markdown]
# #### Common Errors

# %%
# SyntaxError - Missing closing parenthesis
print("Hello World"
# Out:
#   Cell In[97], line 2
#     print("Hello World"
#                        ^
# SyntaxError: incomplete input

# %%
# TypeError - Trying to add a string and an integer
result = "5" + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 2
#       1 # TypeError - Trying to add a string and an integer
# ----> 2 result = "5" + 3
#
# TypeError: can only concatenate str (not "int") to str

# %%
# ValueError - Converting a non-numeric string to an integer
number_str = "abc"
result = int(number_str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 3
#       1 # ValueError - Converting a non-numeric string to an integer
#       2 number_str = "abc"
# ----> 3 result = int(number_str)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
# FileNotFoundError - Trying to open a non-existent file
file_path = "non_existent_file.txt"
with open(file_path, "r") as file:
    content = file.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[100], line 3
#       1 # FileNotFoundError - Trying to open a non-existent file
#       2 file_path = "non_existent_file.txt"
# ----> 3 with open(file_path, "r") as file:
#       4     content = file.read()
#
# File ~/anaconda3/lib/python3.10/site-packages/IPython/core/interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'non_existent_file.txt'

# %% [markdown]
# #### try / except

# %%
a = 5
b = 0

try:
    print(a / b)
except:
    print("Cannot divide by zero!")

print("Completed!")
# Out:
# Cannot divide by zero!
# Completed!

# %%
x = 2

try:
#     y += 3

#     x += "abc"

    x += 2
    print(x)

except Exception as e:
    print("Oops! something went wrong")
    print(type(e))
    print(e)

print("\nThis line is printed anyways")
# Out:
# 4
#
# This line is printed anyways

# %% [markdown]
# #### Raise an error

# %%
# Using raise
def divide(a, b):
    if b == 0:
        raise Exception ("Cannot divide by zero")
    return a / b

# %%
try:
#     result = divide(10, 2)
    result = divide(10, 0)
    print(result)
except Exception as e:
    print(e)
# Out:
# Cannot divide by zero

# %% [markdown]
# #### Multiple Exceptions

# %%
# Catching Specific Exceptions in Python
try:
    even_numbers = [2, 4, 6, 8]

    print(even_numbers[5])

    x = 5 / 0

except IndexError:
    print("Index Out of Bound.")

except ZeroDivisionError:
    print("Denominator cannot be 0.")

print("\nI handled the errors!")
# Out:
# Index Out of Bound.
#
# I handled the errors!

# %% [markdown]
# #### try / except / else

# %%
# Use else after except

try:
    num = int(input("Enter a number: "))
    assert num % 2 == 0
except:
    print("\nNot an even number!")
else:
    reciprocal = 1/num
    print()
    print(reciprocal)
finally:
    print("\nRun Completed!")
# Out:
# Enter a number: 4
#
# 0.25
#
# Run Completed!

# %% [markdown]
# #### Custom Exception

# %%
# Create Custom Exception
class CustomError(Exception):

    def __init__(self, message):
        self.message = message

# %%
try:
    raise CustomError("This is a custom error!")

except Exception as e:
    print(e.message)
# Out:
# This is a custom error!

# %% [markdown]
# ### File Handling

# %% [markdown]
# #### Read file - 1

# %%
# Open a file
file = open("test1.txt", "r")

# Then read the file
content = file.read()

print(type(content))
print()
print(content)

file.close()
# Out:
# <class 'str'>
#
# hey, how are you?
# I am good, what about you?
# I am also good.Writing at the endWriting at the end

# %% [markdown]
# #### Read file - 2

# %%
# Open an close in one shot (to avoid resource leak)
with open("test1.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# hey, how are you?
# I am good, what about you?
# I am also good.Writing at the endWriting at the end

# %% [markdown]
# #### readline()

# %%
# readline()
with open("test1.txt", "r") as file:

    cur_line = file.readline()
    print(cur_line)

    cur_line = file.readline()
    print(cur_line)

    cur_line = file.readline()
    print(cur_line)
# Out:
# hey, how are you?
#
# I am good, what about you?
#
# I am also good.Writing at the endWriting at the end

# %%
with open('test1.txt', 'r') as file:
    while True:
        cur_line = file.readline()
        if cur_line:
            print(cur_line)
        else:
            break
# Out:
# hey, how are you?
#
# I am good, what about you?
#
# I am also good.Writing at the endWriting at the end

# %% [markdown]
# #### readlines()

# %%
# Readlines()
with open('test1.txt', 'r') as file:
    lines = file.readlines()
    print(lines)
# Out:
# ['hey, how are you?\n', 'I am good, what about you?\n', 'I am also good.Writing at the endWriting at the end']

# %%
for line in lines:
    print(line)
# Out:
# hey, how are you?
#
# I am good, what about you?
#
# I am also good.Writing at the endWriting at the end

# %% [markdown]
# #### Explore the file

# %%
# Navigate through the file
with open("test1.txt", 'r') as file:

    # Move to another character
    file.seek(5)
    print(file.read())

    print()

    # Find the position of the current character
    position = file.tell()
    print("Currently at position:", position)
# Out:
# how are you?
# I am good, what about you?
# I am also good.Writing at the endWriting at the end
#
# Currently at position: 96

# %% [markdown]
# #### Write

# %%
# How to write a file
file = open("test2.txt", "w")
file.write("Hello John!\nHow are you?")
file.close()

# %%
# Create a new file OR erase and overwrite
with open('test2.txt', 'w') as file:

    # write contents to the test5.txt file
    file.write('Programming is Fun.\n')
    file.write('Python for beginners')

# %% [markdown]
# #### writelines()

# %%
# Write multiple lines
with open('test3.txt', 'w') as file:
    L = ["This is Lagos \n", "This is Python \n", "This is Fcc \n"]
    file.write("Hello There \n")
    file.writelines(L)

# %%
with open('test3.txt', 'a') as file:
    file.write("This is the end of the document")

# %% [markdown]
# #### Class Activity

# %% [markdown]
# 1. Create a new text file named 'my_file.txt' and add the lines:
# ["I love Python.", "Python is my favorite."] (in two separate lines)

# %%
with open('my_file.txt', 'w') as file:
    L = ["I love Python.\n", "Python is my favorite."]
    file.writelines(L)

# %%
with open('my_file.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# I love Python.
# Python is my favorite.

# %% [markdown]
# 2. The append a new line: "Yes! Python is great!"

# %%
with open('my_file.txt', 'a') as file:
    file.write("\nYes! Python is great!")

# %%
with open('my_file.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# I love Python.
# Python is my favorite.
# Yes! Python is great!

# %% [markdown]
# 3. Iterate through lines and at each iteration find the location of "Python"
# (Hint: use str.index(...))

# %%
with open('my_file.txt', 'r') as file:
    lines = file.readlines()

# %%
idx = []

for line in lines:
    new_idx = line.index("Python")
    idx.append(new_idx)

print(idx)
# Out:
# [7, 0, 5]

# %% [markdown]
# #### Simultaneous Read/Write

# %%
with open('new_file.txt', 'r+') as file:

    # Read existing content
    content = file.read()
    print("Existing content:\n\n", content)

    # Move the file pointer to the beginning
    file.seek(0)

    # Write new content
    file.write("New content added!")

    # Move the file pointer to the end
    file.seek(0, 2)

    # Write additional content
    file.write("\nAdditional content appended!")

    # Move the file pointer to the beginning
    file.seek(0)

    # Read the updated content
    updated_content = file.read()
    print("\nUpdated content:\n\n", updated_content)
# Out:
# Existing content:
#
#  Sample text
#
# Updated content:
#
#  New content added!
# Additional content appended!

# %% [markdown]
# ### JSON Module

# %%
import json

# %% [markdown]
# #### Serialize to JSON string

# %%
# Define a Python dictionary
person = {
    "name": "John",
    "age": 30,
    "city": "New York",
    "hasChildren": False,
    "titles": ["engineer", "programmer"]
}

# %%
# Convert into JSON
person_json = json.dumps(person)

# %%
print(type(person_json))
# Out:
# <class 'str'>

# %%
print(person_json)
# Out:
# {"name": "John", "age": 30, "city": "New York", "hasChildren": false, "titles": ["engineer", "programmer"]}

# %%
# use different formatting style
person_json2 = json.dumps(person, indent=4, separators=(", ", " = "), sort_keys=True)

print(person_json2)
# Out:
# {
#     "age" = 30,
#     "city" = "New York",
#     "hasChildren" = false,
#     "name" = "John",
#     "titles" = [
#         "engineer",
#         "programmer"
#     ]
# }

# %% [markdown]
# #### Serialize to a JSON file

# %%
# Define a Python dictionary
person = {
    "name": "John",
    "age": 30,
    "city": "New York",
    "hasChildren": False,
    "titles": ["engineer", "programmer"]
}

# %%
# Write the dictionary "person" on a new file "person1.json"
with open('person1.json', 'w') as file:
    json.dump(person, file)

# %%
# Load the json file as a Python dictionary
with open('person1.json', 'r') as file:
    loaded_person = json.load(file)

# %%
print(type(loaded_person))
# Out:
# <class 'dict'>

# %%
print(loaded_person)
# Out:
# {'name': 'John', 'age': 30, 'city': 'New York', 'hasChildren': False, 'titles': ['engineer', 'programmer']}

# %%
loaded_person['name']
# Out:
# 'John'

# %% [markdown]
# #### Deserialized JSON

# %%
person_json = """
    {
        "age": 30,
        "city": "New York",
        "hasChildren": false,
        "name": "John",
        "titles": [
            "engineer",
            "programmer"
        ]
    }
"""

# %%
# Load JSON-formatted string
person = json.loads(person_json)

# %%
print(type(person))
# Out:
# <class 'dict'>

# %%
print(person)
# Out:
# {'age': 30, 'city': 'New York', 'hasChildren': False, 'name': 'John', 'titles': ['engineer', 'programmer']}

# %%
print(person['city'])
# Out:
# New York

# %% [markdown]
# #### Mix with class

# %%
# Define a new class
class Laptop:

    def __init__(self, name, processor, hdd, ram, cost):
        self.name = name
        self.processor = processor
        self.hdd = hdd
        self.ram = ram
        self.cost = cost

# Create an object of the class
laptop1 = Laptop('Dell Alienware', 'Intel Core i7', 512, 8, 2500.00)

# Convert to key-value pairs
dict1 = laptop1.__dict__

print(type(dict1))
print()
print(dict1)
# Out:
# <class 'dict'>
#
# {'name': 'Dell Alienware', 'processor': 'Intel Core i7', 'hdd': 512, 'ram': 8, 'cost': 2500.0}

# %%
# convert to JSON string
jsonStr = json.dumps(dict1)

# print json string
print(type(jsonStr))
print()
print(jsonStr)
# Out:
# <class 'str'>
#
# {"name": "Dell Alienware", "processor": "Intel Core i7", "hdd": 512, "ram": 8, "cost": 2500.0}
